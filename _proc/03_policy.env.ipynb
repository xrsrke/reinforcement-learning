# %% [raw]
# ---
# description: Fill in a module description here
# output-file: policy.env.html
# title: Rewards
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(extract_transitions)
# Out:
# ---
#
# [source](https://github.com/xrsrke/reinforcement-learning/blob/main/octopus/nn/policy/env.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### extract_transitions
#
# >      extract_transitions (transitions)

# %%
#| echo: false
#| output: asis
show_doc(generate_transitions)
# Out:
# ---
#
# [source](https://github.com/xrsrke/reinforcement-learning/blob/main/octopus/nn/policy/env.py#L22){target="_blank" style="float:right; font-size:smaller"}
#
# ### generate_transitions
#
# >      generate_transitions (model, env)
