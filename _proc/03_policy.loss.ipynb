# %% [raw]
# ---
# description: Fill in a module description here
# output-file: policy.loss.html
# title: Loss
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# $-\gamma_t * G_t * \log \pi_s(a \mid \theta)$
#
# $G_t$: is called the sum of all rewards until time $t$
# - $G_t=r_t+r_{t+1} \ldots+r_{T-1}+r_T$

# %%
#| echo: false
#| output: asis
show_doc(loss_func)
# Out:
# ---
#
# [source](https://github.com/xrsrke/reinforcement-learning/blob/main/octopus/policy/loss.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### loss_func
#
# >      loss_func (selected_actions, discounted_rewards)

# %%
#| echo: false
#| output: asis
show_doc(reinforce_loss)
# Out:
# ---
#
# [source](https://github.com/xrsrke/reinforcement-learning/blob/main/octopus/policy/loss.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### reinforce_loss
#
# >      reinforce_loss (log_probs:torch.Tensor, rewards:torch.Tensor,
# >                      discount_factor:float)

# %%
log_probs = [torch.tensor(0.1).log(), torch.tensor(0.2).log(), torch.tensor(0.3).log()]
rewards = [torch.tensor(1), torch.tensor(2), torch.tensor(3)]

# %%
reinforce_loss(log_probs, rewards, discount_factor=0.99)
# Out:
# tensor(8.4143)
