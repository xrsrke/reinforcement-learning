# %% [raw]
# ---
# description: Fill in a module description here
# output-file: utils.html
# title: utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(plot)
# Out:
# ---
#
# [source](https://github.com/xrsrke/reinforcement-learning/blob/main/octopus/utils.py#L13){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot
#
# >      plot (data, xlabel, ylabel)

# %% [markdown]
# ### Policy Network

# %%
#| echo: false
#| output: asis
show_doc(evaluate_policy_agent)
# Out:
# ---
#
# [source](https://github.com/xrsrke/reinforcement-learning/blob/main/octopus/utils.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### evaluate_policy_agent
#
# >      evaluate_policy_agent (env, model, n_episodes)

# %%
#| echo: false
#| output: asis
show_doc(simulate_policy_agent)
# Out:
# ---
#
# [source](https://github.com/xrsrke/reinforcement-learning/blob/main/octopus/utils.py#L52){target="_blank" style="float:right; font-size:smaller"}
#
# ### simulate_policy_agent
#
# >      simulate_policy_agent (env_id, model)
