# %% [raw]
# ---
# description: Fill in a module description here
# output-file: policy.evaluate.html
# title: Evaluate Policy Agent
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(evaluate_agent)
# Out:
# ---
#
# [source](https://github.com/xrsrke/reinforcement-learning/blob/main/octopus/policy/evaluate.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### evaluate_agent
#
# >      evaluate_agent (policy, env, max_steps, n_eval_episodes)
