# %% [raw]
# ---
# description: Fill in a module description here
# output-file: policy.reward.html
# title: Rewards
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ### Discounted Rewards

# %%
#| echo: false
#| output: asis
show_doc(discount_rewards)
# Out:
# ---
#
# [source](https://github.com/xrsrke/reinforcement-learning/blob/main/octopus/nn/policy/rewards.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### discount_rewards
#
# >      discount_rewards (rewards, discount_factor)
