# %%
from typing import List

import torch
from torch import nn
from torch import optim
from torch.distributions import Categorical
import gym

from octopus.policy.reward import calculate_discounted_return_each_timestep, calculate_advantages

# %%
class ActorNet(nn.Module):
    def __init__(self, n_observations, n_actions, hidden_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_observations, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions),
            nn.Softmax(dim=-1)
        )
    
    def forward(self, state):
        return self.layers(state)

# %%
class CriticNet(nn.Module):
    def __init__(self, n_observations, n_actions, hidden_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_observations, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 1)
        )
    
    def forward(self, state):
        return self.layers(state)

# %%
# class A2C(nn.Module):
#     def __init__(self, n_observations, n_actions, hidden_size):
#         super().__init__()
#         self.actor = nn.Sequential(
#             nn.Linear(n_observations, hidden_size),
#             nn.ReLU(),
#             nn.Linear(hidden_size, n_actions),
#             nn.Softmax(dim=-1)
#         )
        
#         self.critic = nn.Sequential(
#             nn.Linear(n_observations, hidden_size),
#             nn.ReLU(),
#             nn.Linear(hidden_size, 1)
#         )
    
#     def forward(self, state):
#         pred_action = self.actor(state)
#         pred_value = self.critic(state)
        
#         return pred_action, pred_value

# %%
env = gym.make('CartPole-v1')

# %%
n_observations = env.observation_space.shape[0]
n_actions = env.action_space.n

actor = ActorNet(n_observations, n_actions, hidden_size=128)
critic = CriticNet(n_observations, n_actions, hidden_size=128)

LEARNING_RATE = 0.001

actor_optim = optim.Adam(actor.parameters(), lr=LEARNING_RATE)
critic_optim = optim.Adam(critic.parameters(), lr=LEARNING_RATE)
    
critic_loss_func = nn.MSELoss()

# %%
def compute_actor_loss(log_probs: List[torch.Tensor], advantages: List[torch.Tensor]):
    """Calculate the advantage loss for actor

    Args:
        log_probs (_type_): a list of 
        advantages (_type_): _description_

    Returns:
        _type_: _description_
    """
    assert len(log_probs) == len(advantages)
    
    total_loss = 0
    for log_prob, advantage in zip(log_probs, advantages):
        total_loss = log_prob * advantage
    
    # return -(torch.sum(log_probs * advantages))
    return -total_loss

# %%
N_EPISODES = 10000
DISCOUNT_FACTOR = 0.99

episode_rewards = []
episode_actor_losses = []
episode_critic_losses = []

for episode in range(N_EPISODES):
    
    pred_log_probs = []
    pred_q_values = []
    rewards = []
    total_reward = 0

    observation, _ = env.reset()
    observation = torch.from_numpy(observation)
    in_progress = True
    
    while in_progress:
        pred_action = actor(observation)
        pred_value = critic(observation)

        action_idx = Categorical(pred_action).sample().item()
                        
        new_observation, reward, done, truncated, info = env.step(action_idx)
        reward = torch.tensor(reward)
        
        pred_log_probs.append(pred_action[action_idx].log())
        pred_q_values.append(pred_value)
        rewards.append(reward)
        total_reward += reward
        
        if done: break
    
    episode_rewards.append(total_reward)
    
    # TODO: this one make it loss grad
    # pred_q_values = torch.tensor(pred_q_values)
    
    discounted_returns = calculate_discounted_return_each_timestep(rewards, DISCOUNT_FACTOR)
    advantages = calculate_advantages(discounted_returns, torch.tensor(pred_q_values))
    loss_actor = compute_actor_loss(pred_log_probs, advantages)
    
    _pred_q_values = torch.tensor(pred_q_values)
    _pred_q_values.requires_grad = True
    loss_critic = critic_loss_func(discounted_returns, _pred_q_values)
    
    episode_actor_losses.append(loss_actor.detach().numpy())
    episode_critic_losses.append(loss_critic.detach().numpy())
    
    actor_optim.zero_grad()
    critic_optim.zero_grad()
    
    loss_actor.backward()
    loss_critic.backward()
    
    actor_optim.step()
    critic_optim.step()
    
    print(f"episode={episode} loss_actor={loss_actor}, loss_critic={loss_critic}")

# %%
import matplotlib.pyplot as plt
plt.plot(episode_rewards)
# Out:
# [<matplotlib.lines.Line2D at 0x1335c4dc0>]

# %%
episode_rewards
# Out:
# [tensor(27.),
#  tensor(23.),
#  tensor(23.),
#  tensor(48.),
#  tensor(11.),
#  tensor(26.),
#  tensor(12.),
#  tensor(37.),
#  tensor(11.),
#  tensor(30.),
#  tensor(14.),
#  tensor(33.),
#  tensor(19.),
#  tensor(26.),
#  tensor(16.),
#  tensor(14.),
#  tensor(29.),
#  tensor(16.),
#  tensor(37.),
#  tensor(14.),
#  tensor(20.),
#  tensor(14.),
#  tensor(23.),
#  tensor(32.),
#  tensor(15.),
#  tensor(30.),
#  tensor(8.),
#  tensor(30.),
#  tensor(16.),
#  tensor(21.),
#  tensor(15.),
#  tensor(9.),
#  tensor(14.),
#  tensor(36.),
#  tensor(10.),
#  tensor(33.),
#  tensor(43.),
#  tensor(21.),
#  tensor(19.),
#  tensor(37.),
#  tensor(14.),
#  tensor(57.),
#  tensor(20.),
#  tensor(12.),
#  tensor(10.),
#  tensor(34.),
#  tensor(19.),
#  tensor(13.),
#  tensor(15.),
#  tensor(14.),
#  tensor(21.),
#  tensor(12.),
#  tensor(16.),
#  tensor(17.),
#  tensor(21.),
#  tensor(15.),
#  tensor(22.),
#  tensor(16.),
#  tensor(10.),
#  tensor(13.),
#  tensor(52.),
#  tensor(10.),
#  tensor(12.),
#  tensor(19.),
#  tensor(20.),
#  tensor(13.),
#  tensor(11.),
#  tensor(32.),
#  tensor(10.),
#  tensor(20.),
#  tensor(14.),
#  tensor(54.),
#  tensor(23.),
#  tensor(12.),
#  tensor(18.),
#  tensor(10.),
#  tensor(20.),
#  tensor(23.),
#  tensor(15.),
#  tensor(26.),
#  tensor(35.),
#  tensor(21.),
#  tensor(29.),
#  tensor(36.),
#  tensor(18.),
#  tensor(11.),
#  tensor(40.),
#  tensor(22.),
#  tensor(16.),
#  tensor(8.),
#  tensor(14.),
#  tensor(16.),
#  tensor(18.),
#  tensor(14.),
#  tensor(23.),
#  tensor(16.),
#  tensor(29.),
#  tensor(54.),
#  tensor(12.),
#  tensor(9.),
#  tensor(13.),
#  tensor(18.),
#  tensor(38.),
#  tensor(56.),
#  tensor(12.),
#  tensor(36.),
#  tensor(9.),
#  tensor(13.),
#  tensor(15.),
#  tensor(12.),
#  tensor(24.),
#  tensor(13.),
#  tensor(50.),
#  tensor(14.),
#  tensor(20.),
#  tensor(26.),
#  tensor(15.),
#  tensor(11.),
#  tensor(46.),
#  tensor(21.),
#  tensor(23.),
#  tensor(34.),
#  tensor(19.),
#  tensor(24.),
#  tensor(17.),
#  tensor(24.),
#  tensor(16.),
#  tensor(14.),
#  tensor(14.),
#  tensor(18.),
#  tensor(17.),
#  tensor(29.),
#  tensor(25.),
#  tensor(24.),
#  tensor(28.),
#  tensor(34.),
#  tensor(26.),
#  tensor(9.),
#  tensor(25.),
#  tensor(29.),
#  tensor(15.),
#  tensor(13.),
#  tensor(32.),
#  tensor(18.),
#  tensor(21.),
#  tensor(19.),
#  tensor(28.),
#  tensor(19.),
#  tensor(20.),
#  tensor(29.),
#  tensor(15.),
#  tensor(11.),
#  tensor(24.),
#  tensor(10.),
#  tensor(18.),
#  tensor(16.),
#  tensor(57.),
#  tensor(18.),
#  tensor(13.),
#  tensor(13.),
#  tensor(12.),
#  tensor(15.),
#  tensor(27.),
#  tensor(13.),
#  tensor(37.),
#  tensor(29.),
#  tensor(69.),
#  tensor(26.),
#  tensor(12.),
#  tensor(20.),
#  tensor(30.),
#  tensor(25.),
#  tensor(29.),
#  tensor(17.),
#  tensor(12.),
#  tensor(14.),
#  tensor(47.),
#  tensor(12.),
#  tensor(11.),
#  tensor(23.),
#  tensor(9.),
#  tensor(13.),
#  tensor(14.),
#  tensor(73.),
#  tensor(13.),
#  tensor(12.),
#  tensor(19.),
#  tensor(30.),
#  tensor(43.),
#  tensor(17.),
#  tensor(20.),
#  tensor(42.),
#  tensor(18.),
#  tensor(37.),
#  tensor(42.),
#  tensor(10.),
#  tensor(14.),
#  tensor(26.),
#  tensor(10.),
#  tensor(19.),
#  tensor(37.),
#  tensor(29.),
#  tensor(37.),
#  tensor(11.),
#  tensor(46.),
#  tensor(66.),
#  tensor(13.),
#  tensor(10.),
#  tensor(11.),
#  tensor(28.),
#  tensor(14.),
#  tensor(17.),
#  tensor(21.),
#  tensor(18.),
#  tensor(17.),
#  tensor(14.),
#  tensor(11.),
#  tensor(14.),
#  tensor(13.),
#  tensor(11.),
#  tensor(14.),
#  tensor(21.),
#  tensor(21.),
#  tensor(35.),
#  tensor(20.),
#  tensor(16.),
#  tensor(23.),
#  tensor(23.),
#  tensor(10.),
#  tensor(21.),
#  tensor(24.),
#  tensor(21.),
#  tensor(12.),
#  tensor(26.),
#  tensor(20.),
#  tensor(18.),
#  tensor(40.),
#  tensor(26.),
#  tensor(19.),
#  tensor(25.),
#  tensor(10.),
#  tensor(13.),
#  tensor(14.),
#  tensor(21.),
#  tensor(9.),
#  tensor(41.),
#  tensor(29.),
#  tensor(9.),
#  tensor(18.),
#  tensor(13.),
#  tensor(11.),
#  tensor(12.),
#  tensor(12.),
#  tensor(14.),
#  tensor(28.),
#  tensor(11.),
#  tensor(18.),
#  tensor(91.),
#  tensor(15.),
#  tensor(27.),
#  tensor(17.),
#  tensor(24.),
#  tensor(28.),
#  tensor(16.),
#  tensor(17.),
#  tensor(16.),
#  tensor(59.),
#  tensor(20.),
#  tensor(15.),
#  tensor(21.),
#  tensor(19.),
#  tensor(17.),
#  tensor(16.),
#  tensor(10.),
#  tensor(13.),
#  tensor(31.),
#  tensor(11.),
#  tensor(17.),
#  tensor(19.),
#  tensor(25.),
#  tensor(12.),
#  tensor(12.),
#  tensor(33.),
#  tensor(11.),
#  tensor(17.),
#  tensor(16.),
#  tensor(33.),
#  tensor(30.),
#  tensor(12.),
#  tensor(23.),
#  tensor(23.),
#  tensor(20.),
#  tensor(12.),
#  tensor(14.),
#  tensor(11.),
#  tensor(18.),
#  tensor(10.),
#  tensor(16.),
#  tensor(18.),
#  tensor(12.),
#  tensor(11.),
#  tensor(25.),
#  tensor(12.),
#  tensor(22.),
#  tensor(18.),
#  tensor(31.),
#  tensor(19.),
#  tensor(24.),
#  tensor(8.),
#  tensor(12.),
#  tensor(35.),
#  tensor(13.),
#  tensor(23.),
#  tensor(10.),
#  tensor(30.),
#  tensor(13.),
#  tensor(12.),
#  tensor(15.),
#  tensor(15.),
#  tensor(17.),
#  tensor(33.),
#  tensor(10.),
#  tensor(38.),
#  tensor(11.),
#  tensor(19.),
#  tensor(9.),
#  tensor(19.),
#  tensor(17.),
#  tensor(21.),
#  tensor(22.),
#  tensor(18.),
#  tensor(17.),
#  tensor(9.),
#  tensor(15.),
#  tensor(15.),
#  tensor(15.),
#  tensor(30.),
#  tensor(14.),
#  tensor(22.),
#  tensor(10.),
#  tensor(19.),
#  tensor(24.),
#  tensor(21.),
#  tensor(12.),
#  tensor(12.),
#  tensor(13.),
#  tensor(23.),
#  tensor(12.),
#  tensor(22.),
#  tensor(21.),
#  tensor(12.),
#  tensor(18.),
#  tensor(14.),
#  tensor(17.),
#  tensor(19.),
#  tensor(29.),
#  tensor(21.),
#  tensor(28.),
#  tensor(15.),
#  tensor(14.),
#  tensor(19.),
#  tensor(11.),
#  tensor(11.),
#  tensor(41.),
#  tensor(13.),
#  tensor(32.),
#  tensor(17.),
#  tensor(35.),
#  tensor(18.),
#  tensor(33.),
#  tensor(18.),
#  tensor(20.),
#  tensor(23.),
#  tensor(44.),
#  tensor(32.),
#  tensor(12.),
#  tensor(21.),
#  tensor(22.),
#  tensor(24.),
#  tensor(12.),
#  tensor(15.),
#  tensor(9.),
#  tensor(13.),
#  tensor(49.),
#  tensor(19.),
#  tensor(15.),
#  tensor(23.),
#  tensor(15.),
#  tensor(28.),
#  tensor(21.),
#  tensor(16.),
#  tensor(15.),
#  tensor(32.),
#  tensor(14.),
#  tensor(22.),
#  tensor(14.),
#  tensor(22.),
#  tensor(13.),
#  tensor(12.),
#  tensor(25.),
#  tensor(15.),
#  tensor(13.),
#  tensor(12.),
#  tensor(46.),
#  tensor(14.),
#  tensor(15.),
#  tensor(27.),
#  tensor(30.),
#  tensor(11.),
#  tensor(21.),
#  tensor(66.),
#  tensor(10.),
#  tensor(26.),
#  tensor(22.),
#  tensor(10.),
#  tensor(35.),
#  tensor(21.),
#  tensor(43.),
#  tensor(20.),
#  tensor(14.),
#  tensor(15.),
#  tensor(8.),
#  tensor(15.),
#  tensor(25.),
#  tensor(9.),
#  tensor(17.),
#  tensor(21.),
#  tensor(33.),
#  tensor(25.),
#  tensor(13.),
#  tensor(34.),
#  tensor(22.),
#  tensor(12.),
#  tensor(14.),
#  tensor(15.),
#  tensor(17.),
#  tensor(10.),
#  tensor(26.),
#  tensor(13.),
#  tensor(11.),
#  tensor(14.),
#  tensor(19.),
#  tensor(15.),
#  tensor(11.),
#  tensor(26.),
#  tensor(19.),
#  tensor(25.),
#  tensor(14.),
#  tensor(13.),
#  tensor(16.),
#  tensor(14.),
#  tensor(9.),
#  tensor(12.),
#  tensor(30.),
#  tensor(11.),
#  tensor(17.),
#  tensor(18.),
#  tensor(16.),
#  tensor(10.),
#  tensor(14.),
#  tensor(12.),
#  tensor(10.),
#  tensor(38.),
#  tensor(15.),
#  tensor(19.),
#  tensor(13.),
#  tensor(27.),
#  tensor(16.),
#  tensor(15.),
#  tensor(11.),
#  tensor(12.),
#  tensor(11.),
#  tensor(15.),
#  tensor(12.),
#  tensor(21.),
#  tensor(11.),
#  tensor(20.),
#  tensor(9.),
#  tensor(13.),
#  tensor(15.),
#  tensor(27.),
#  tensor(19.),
#  tensor(13.),
#  tensor(56.),
#  tensor(28.),
#  tensor(11.),
#  tensor(32.),
#  tensor(36.),
#  tensor(30.),
#  tensor(16.),
#  tensor(37.),
#  tensor(11.),
#  tensor(18.),
#  tensor(29.),
#  tensor(15.),
#  tensor(9.),
#  tensor(17.),
#  tensor(11.),
#  tensor(22.),
#  tensor(12.),
#  tensor(21.),
#  tensor(9.),
#  tensor(52.),
#  tensor(11.),
#  tensor(20.),
#  tensor(14.),
#  tensor(13.),
#  tensor(9.),
#  tensor(12.),
#  tensor(17.),
#  tensor(14.),
#  tensor(10.),
#  tensor(9.),
#  tensor(13.),
#  tensor(17.),
#  tensor(16.),
#  tensor(14.),
#  tensor(17.),
#  tensor(11.),
#  tensor(24.),
#  tensor(10.),
#  tensor(20.),
#  tensor(22.),
#  tensor(31.),
#  tensor(23.),
#  tensor(10.),
#  tensor(14.),
#  tensor(19.),
#  tensor(20.),
#  tensor(10.),
#  tensor(23.),
#  tensor(17.),
#  tensor(12.),
#  tensor(12.),
#  tensor(21.),
#  tensor(19.),
#  tensor(10.),
#  tensor(17.),
#  tensor(13.),
#  tensor(25.),
#  tensor(16.),
#  tensor(15.),
#  tensor(15.),
#  tensor(23.),
#  tensor(12.),
#  tensor(11.),
#  tensor(9.),
#  tensor(12.),
#  tensor(11.),
#  tensor(38.),
#  tensor(26.),
#  tensor(14.),
#  tensor(12.),
#  tensor(12.),
#  tensor(12.),
#  tensor(10.),
#  tensor(10.),
#  tensor(10.),
#  tensor(17.),
#  tensor(10.),
#  tensor(17.),
#  tensor(12.),
#  tensor(11.),
#  tensor(11.),
#  tensor(11.),
#  tensor(16.),
#  tensor(16.),
#  tensor(13.),
#  tensor(23.),
#  tensor(13.),
#  tensor(14.),
#  tensor(18.),
#  tensor(10.),
#  tensor(16.),
#  tensor(16.),
#  tensor(16.),
#  tensor(18.),
#  tensor(9.),
#  tensor(10.),
#  tensor(10.),
#  tensor(15.),
#  tensor(21.),
#  tensor(12.),
#  tensor(18.),
#  tensor(14.),
#  tensor(14.),
#  tensor(30.),
#  tensor(27.),
#  tensor(9.),
#  tensor(9.),
#  tensor(23.),
#  tensor(37.),
#  tensor(15.),
#  tensor(13.),
#  tensor(18.),
#  tensor(15.),
#  tensor(9.),
#  tensor(15.),
#  tensor(10.),
#  tensor(12.),
#  tensor(23.),
#  tensor(10.),
#  tensor(15.),
#  tensor(14.),
#  tensor(12.),
#  tensor(17.),
#  tensor(14.),
#  tensor(13.),
#  tensor(12.),
#  tensor(10.),
#  tensor(12.),
#  tensor(15.),
#  tensor(11.),
#  tensor(32.),
#  tensor(14.),
#  tensor(11.),
#  tensor(20.),
#  tensor(12.),
#  tensor(15.),
#  tensor(15.),
#  tensor(12.),
#  tensor(12.),
#  tensor(10.),
#  tensor(20.),
#  tensor(10.),
#  tensor(21.),
#  tensor(12.),
#  tensor(12.),
#  tensor(13.),
#  tensor(13.),
#  tensor(15.),
#  tensor(16.),
#  tensor(12.),
#  tensor(15.),
#  tensor(10.),
#  tensor(22.),
#  tensor(21.),
#  tensor(10.),
#  tensor(14.),
#  tensor(11.),
#  tensor(29.),
#  tensor(9.),
#  tensor(10.),
#  tensor(11.),
#  tensor(21.),
#  tensor(17.),
#  tensor(12.),
#  tensor(13.),
#  tensor(8.),
#  tensor(11.),
#  tensor(10.),
#  tensor(11.),
#  tensor(15.),
#  tensor(21.),
#  tensor(11.),
#  tensor(16.),
#  tensor(18.),
#  tensor(19.),
#  tensor(9.),
#  tensor(13.),
#  tensor(12.),
#  tensor(24.),
#  tensor(14.),
#  tensor(20.),
#  tensor(9.),
#  tensor(21.),
#  tensor(11.),
#  tensor(13.),
#  tensor(8.),
#  tensor(14.),
#  tensor(13.),
#  tensor(12.),
#  tensor(12.),
#  tensor(15.),
#  tensor(13.),
#  tensor(10.),
#  tensor(12.),
#  tensor(13.),
#  tensor(10.),
#  tensor(11.),
#  tensor(10.),
#  tensor(12.),
#  tensor(10.),
#  tensor(11.),
#  tensor(16.),
#  tensor(14.),
#  tensor(14.),
#  tensor(22.),
#  tensor(10.),
#  tensor(9.),
#  tensor(10.),
#  tensor(9.),
#  tensor(11.),
#  tensor(13.),
#  tensor(14.),
#  tensor(9.),
#  tensor(9.),
#  tensor(10.),
#  tensor(16.),
#  tensor(10.),
#  tensor(11.),
#  tensor(12.),
#  tensor(11.),
#  tensor(10.),
#  tensor(15.),
#  tensor(14.),
#  tensor(10.),
#  tensor(23.),
#  tensor(15.),
#  tensor(16.),
#  tensor(19.),
#  tensor(14.),
#  tensor(13.),
#  tensor(27.),
#  tensor(15.),
#  tensor(17.),
#  tensor(12.),
#  tensor(8.),
#  tensor(15.),
#  tensor(14.),
#  tensor(8.),
#  tensor(18.),
#  tensor(12.),
#  tensor(10.),
#  tensor(9.),
#  tensor(28.),
#  tensor(14.),
#  tensor(14.),
#  tensor(26.),
#  tensor(11.),
#  tensor(12.),
#  tensor(8.),
#  tensor(12.),
#  tensor(11.),
#  tensor(10.),
#  tensor(8.),
#  tensor(12.),
#  tensor(14.),
#  tensor(16.),
#  tensor(10.),
#  tensor(14.),
#  tensor(15.),
#  tensor(12.),
#  tensor(12.),
#  tensor(16.),
#  tensor(9.),
#  tensor(13.),
#  tensor(17.),
#  tensor(11.),
#  tensor(14.),
#  tensor(14.),
#  tensor(15.),
#  tensor(13.),
#  tensor(13.),
#  tensor(12.),
#  tensor(15.),
#  tensor(14.),
#  tensor(13.),
#  tensor(10.),
#  tensor(15.),
#  tensor(11.),
#  tensor(10.),
#  tensor(21.),
#  tensor(12.),
#  tensor(11.),
#  tensor(11.),
#  tensor(19.),
#  tensor(12.),
#  tensor(13.),
#  tensor(15.),
#  tensor(13.),
#  tensor(12.),
#  tensor(24.),
#  tensor(9.),
#  tensor(20.),
#  tensor(17.),
#  tensor(12.),
#  tensor(14.),
#  tensor(21.),
#  tensor(13.),
#  tensor(18.),
#  tensor(11.),
#  tensor(31.),
#  tensor(25.),
#  tensor(39.),
#  tensor(16.),
#  tensor(23.),
#  tensor(10.),
#  tensor(9.),
#  tensor(11.),
#  tensor(13.),
#  tensor(9.),
#  tensor(15.),
#  tensor(18.),
#  tensor(18.),
#  tensor(10.),
#  tensor(25.),
#  tensor(18.),
#  tensor(12.),
#  tensor(12.),
#  tensor(11.),
#  tensor(10.),
#  tensor(22.),
#  tensor(18.),
#  tensor(14.),
#  tensor(12.),
#  tensor(9.),
#  tensor(8.),
#  tensor(13.),
#  tensor(16.),
#  tensor(16.),
#  tensor(17.),
#  tensor(21.),
#  tensor(13.),
#  tensor(11.),
#  tensor(12.),
#  tensor(15.),
#  tensor(13.),
#  tensor(25.),
#  tensor(15.),
#  tensor(14.),
#  tensor(17.),
#  tensor(12.),
#  tensor(19.),
#  tensor(11.),
#  tensor(12.),
#  tensor(12.),
#  tensor(16.),
#  tensor(10.),
#  tensor(12.),
#  tensor(22.),
#  tensor(9.),
#  tensor(12.),
#  tensor(14.),
#  tensor(12.),
#  tensor(18.),
#  tensor(11.),
#  tensor(15.),
#  tensor(8.),
#  tensor(11.),
#  tensor(24.),
#  tensor(18.),
#  tensor(15.),
#  tensor(16.),
#  tensor(19.),
#  tensor(26.),
#  tensor(13.),
#  tensor(9.),
#  tensor(27.),
#  tensor(14.),
#  tensor(19.),
#  tensor(12.),
#  tensor(12.),
#  tensor(14.),
#  tensor(15.),
#  tensor(15.),
#  tensor(21.),
#  tensor(13.),
#  tensor(12.),
#  tensor(12.),
#  tensor(17.),
#  tensor(13.),
#  tensor(20.),
#  tensor(16.),
#  tensor(12.),
#  tensor(8.),
#  tensor(11.),
#  tensor(14.),
#  tensor(13.),
#  tensor(17.),
#  tensor(12.),
#  tensor(13.),
#  tensor(15.),
#  tensor(10.),
#  tensor(10.),
#  tensor(15.),
#  tensor(12.),
#  tensor(11.),
#  tensor(15.),
#  tensor(11.),
#  tensor(11.),
#  tensor(20.),
#  tensor(8.),
#  tensor(8.),
#  tensor(12.),
#  tensor(17.),
#  tensor(12.),
#  tensor(14.),
#  tensor(11.),
#  tensor(10.),
#  tensor(9.),
#  tensor(10.),
#  tensor(20.),
#  tensor(13.),
#  tensor(12.),
#  tensor(17.),
#  tensor(15.),
#  tensor(14.),
#  tensor(12.),
#  tensor(19.),
#  tensor(9.),
#  tensor(21.),
#  tensor(14.),
#  tensor(10.),
#  tensor(15.),
#  tensor(10.),
#  tensor(12.),
#  tensor(13.),
#  tensor(21.),
#  tensor(19.),
#  tensor(10.),
#  tensor(19.),
#  tensor(10.),
#  tensor(13.),
#  tensor(16.),
#  tensor(14.),
#  tensor(10.),
#  tensor(11.),
#  tensor(11.),
#  tensor(10.),
#  tensor(10.),
#  tensor(12.),
#  tensor(11.),
#  tensor(10.),
#  tensor(12.),
#  tensor(12.),
#  tensor(10.),
#  tensor(8.),
#  tensor(9.),
#  tensor(9.),
#  tensor(11.),
#  tensor(8.),
#  tensor(9.),
#  tensor(12.),
#  tensor(9.),
#  tensor(10.),
#  tensor(17.),
#  tensor(10.),
#  tensor(8.),
#  tensor(15.),
#  tensor(8.),
#  tensor(12.),
#  tensor(12.),
#  tensor(9.),
#  tensor(11.),
#  tensor(10.),
#  tensor(9.),
#  tensor(34.),
#  tensor(31.),
#  tensor(8.),
#  tensor(21.),
#  tensor(21.),
#  tensor(30.),
#  tensor(16.),
#  tensor(9.),
#  tensor(9.),
#  tensor(9.),
#  tensor(10.),
#  tensor(15.),
#  tensor(17.),
#  tensor(12.),
#  tensor(11.),
#  tensor(18.),
#  tensor(13.),
#  tensor(20.),
#  tensor(31.),
#  tensor(12.),
#  tensor(9.),
#  tensor(15.),
#  tensor(29.),
#  tensor(13.),
#  tensor(11.),
#  tensor(15.),
#  tensor(11.),
#  tensor(12.),
#  tensor(25.),
#  tensor(20.),
#  tensor(17.),
#  tensor(10.),
#  tensor(16.),
#  tensor(12.),
#  tensor(13.),
#  tensor(11.),
#  tensor(16.),
#  tensor(10.),
#  tensor(12.),
#  tensor(10.),
#  tensor(11.),
#  tensor(12.),
#  tensor(12.),
#  tensor(12.),
#  tensor(13.),
#  tensor(9.),
#  tensor(9.),
#  tensor(10.),
#  tensor(26.),
#  tensor(11.),
#  tensor(13.),
#  tensor(10.),
#  tensor(12.),
#  ...]

# %%
len(episode_rewards)
# Out:
# 10000

# %%
episode_rewards
# Out:
# [tensor(27.),
#  tensor(23.),
#  tensor(23.),
#  tensor(48.),
#  tensor(11.),
#  tensor(26.),
#  tensor(12.),
#  tensor(37.),
#  tensor(11.),
#  tensor(30.),
#  tensor(14.),
#  tensor(33.),
#  tensor(19.),
#  tensor(26.),
#  tensor(16.),
#  tensor(14.),
#  tensor(29.),
#  tensor(16.),
#  tensor(37.),
#  tensor(14.),
#  tensor(20.),
#  tensor(14.),
#  tensor(23.),
#  tensor(32.),
#  tensor(15.),
#  tensor(30.),
#  tensor(8.),
#  tensor(30.),
#  tensor(16.),
#  tensor(21.),
#  tensor(15.),
#  tensor(9.),
#  tensor(14.),
#  tensor(36.),
#  tensor(10.),
#  tensor(33.),
#  tensor(43.),
#  tensor(21.),
#  tensor(19.),
#  tensor(37.),
#  tensor(14.),
#  tensor(57.),
#  tensor(20.),
#  tensor(12.),
#  tensor(10.),
#  tensor(34.),
#  tensor(19.),
#  tensor(13.),
#  tensor(15.),
#  tensor(14.),
#  tensor(21.),
#  tensor(12.),
#  tensor(16.),
#  tensor(17.),
#  tensor(21.),
#  tensor(15.),
#  tensor(22.),
#  tensor(16.),
#  tensor(10.),
#  tensor(13.),
#  tensor(52.),
#  tensor(10.),
#  tensor(12.),
#  tensor(19.),
#  tensor(20.),
#  tensor(13.),
#  tensor(11.),
#  tensor(32.),
#  tensor(10.),
#  tensor(20.),
#  tensor(14.),
#  tensor(54.),
#  tensor(23.),
#  tensor(12.),
#  tensor(18.),
#  tensor(10.),
#  tensor(20.),
#  tensor(23.),
#  tensor(15.),
#  tensor(26.),
#  tensor(35.),
#  tensor(21.),
#  tensor(29.),
#  tensor(36.),
#  tensor(18.),
#  tensor(11.),
#  tensor(40.),
#  tensor(22.),
#  tensor(16.),
#  tensor(8.),
#  tensor(14.),
#  tensor(16.),
#  tensor(18.),
#  tensor(14.),
#  tensor(23.),
#  tensor(16.),
#  tensor(29.),
#  tensor(54.),
#  tensor(12.),
#  tensor(9.),
#  tensor(13.),
#  tensor(18.),
#  tensor(38.),
#  tensor(56.),
#  tensor(12.),
#  tensor(36.),
#  tensor(9.),
#  tensor(13.),
#  tensor(15.),
#  tensor(12.),
#  tensor(24.),
#  tensor(13.),
#  tensor(50.),
#  tensor(14.),
#  tensor(20.),
#  tensor(26.),
#  tensor(15.),
#  tensor(11.),
#  tensor(46.),
#  tensor(21.),
#  tensor(23.),
#  tensor(34.),
#  tensor(19.),
#  tensor(24.),
#  tensor(17.),
#  tensor(24.),
#  tensor(16.),
#  tensor(14.),
#  tensor(14.),
#  tensor(18.),
#  tensor(17.),
#  tensor(29.),
#  tensor(25.),
#  tensor(24.),
#  tensor(28.),
#  tensor(34.),
#  tensor(26.),
#  tensor(9.),
#  tensor(25.),
#  tensor(29.),
#  tensor(15.),
#  tensor(13.),
#  tensor(32.),
#  tensor(18.),
#  tensor(21.),
#  tensor(19.),
#  tensor(28.),
#  tensor(19.),
#  tensor(20.),
#  tensor(29.),
#  tensor(15.),
#  tensor(11.),
#  tensor(24.),
#  tensor(10.),
#  tensor(18.),
#  tensor(16.),
#  tensor(57.),
#  tensor(18.),
#  tensor(13.),
#  tensor(13.),
#  tensor(12.),
#  tensor(15.),
#  tensor(27.),
#  tensor(13.),
#  tensor(37.),
#  tensor(29.),
#  tensor(69.),
#  tensor(26.),
#  tensor(12.),
#  tensor(20.),
#  tensor(30.),
#  tensor(25.),
#  tensor(29.),
#  tensor(17.),
#  tensor(12.),
#  tensor(14.),
#  tensor(47.),
#  tensor(12.),
#  tensor(11.),
#  tensor(23.),
#  tensor(9.),
#  tensor(13.),
#  tensor(14.),
#  tensor(73.),
#  tensor(13.),
#  tensor(12.),
#  tensor(19.),
#  tensor(30.),
#  tensor(43.),
#  tensor(17.),
#  tensor(20.),
#  tensor(42.),
#  tensor(18.),
#  tensor(37.),
#  tensor(42.),
#  tensor(10.),
#  tensor(14.),
#  tensor(26.),
#  tensor(10.),
#  tensor(19.),
#  tensor(37.),
#  tensor(29.),
#  tensor(37.),
#  tensor(11.),
#  tensor(46.),
#  tensor(66.),
#  tensor(13.),
#  tensor(10.),
#  tensor(11.),
#  tensor(28.),
#  tensor(14.),
#  tensor(17.),
#  tensor(21.),
#  tensor(18.),
#  tensor(17.),
#  tensor(14.),
#  tensor(11.),
#  tensor(14.),
#  tensor(13.),
#  tensor(11.),
#  tensor(14.),
#  tensor(21.),
#  tensor(21.),
#  tensor(35.),
#  tensor(20.),
#  tensor(16.),
#  tensor(23.),
#  tensor(23.),
#  tensor(10.),
#  tensor(21.),
#  tensor(24.),
#  tensor(21.),
#  tensor(12.),
#  tensor(26.),
#  tensor(20.),
#  tensor(18.),
#  tensor(40.),
#  tensor(26.),
#  tensor(19.),
#  tensor(25.),
#  tensor(10.),
#  tensor(13.),
#  tensor(14.),
#  tensor(21.),
#  tensor(9.),
#  tensor(41.),
#  tensor(29.),
#  tensor(9.),
#  tensor(18.),
#  tensor(13.),
#  tensor(11.),
#  tensor(12.),
#  tensor(12.),
#  tensor(14.),
#  tensor(28.),
#  tensor(11.),
#  tensor(18.),
#  tensor(91.),
#  tensor(15.),
#  tensor(27.),
#  tensor(17.),
#  tensor(24.),
#  tensor(28.),
#  tensor(16.),
#  tensor(17.),
#  tensor(16.),
#  tensor(59.),
#  tensor(20.),
#  tensor(15.),
#  tensor(21.),
#  tensor(19.),
#  tensor(17.),
#  tensor(16.),
#  tensor(10.),
#  tensor(13.),
#  tensor(31.),
#  tensor(11.),
#  tensor(17.),
#  tensor(19.),
#  tensor(25.),
#  tensor(12.),
#  tensor(12.),
#  tensor(33.),
#  tensor(11.),
#  tensor(17.),
#  tensor(16.),
#  tensor(33.),
#  tensor(30.),
#  tensor(12.),
#  tensor(23.),
#  tensor(23.),
#  tensor(20.),
#  tensor(12.),
#  tensor(14.),
#  tensor(11.),
#  tensor(18.),
#  tensor(10.),
#  tensor(16.),
#  tensor(18.),
#  tensor(12.),
#  tensor(11.),
#  tensor(25.),
#  tensor(12.),
#  tensor(22.),
#  tensor(18.),
#  tensor(31.),
#  tensor(19.),
#  tensor(24.),
#  tensor(8.),
#  tensor(12.),
#  tensor(35.),
#  tensor(13.),
#  tensor(23.),
#  tensor(10.),
#  tensor(30.),
#  tensor(13.),
#  tensor(12.),
#  tensor(15.),
#  tensor(15.),
#  tensor(17.),
#  tensor(33.),
#  tensor(10.),
#  tensor(38.),
#  tensor(11.),
#  tensor(19.),
#  tensor(9.),
#  tensor(19.),
#  tensor(17.),
#  tensor(21.),
#  tensor(22.),
#  tensor(18.),
#  tensor(17.),
#  tensor(9.),
#  tensor(15.),
#  tensor(15.),
#  tensor(15.),
#  tensor(30.),
#  tensor(14.),
#  tensor(22.),
#  tensor(10.),
#  tensor(19.),
#  tensor(24.),
#  tensor(21.),
#  tensor(12.),
#  tensor(12.),
#  tensor(13.),
#  tensor(23.),
#  tensor(12.),
#  tensor(22.),
#  tensor(21.),
#  tensor(12.),
#  tensor(18.),
#  tensor(14.),
#  tensor(17.),
#  tensor(19.),
#  tensor(29.),
#  tensor(21.),
#  tensor(28.),
#  tensor(15.),
#  tensor(14.),
#  tensor(19.),
#  tensor(11.),
#  tensor(11.),
#  tensor(41.),
#  tensor(13.),
#  tensor(32.),
#  tensor(17.),
#  tensor(35.),
#  tensor(18.),
#  tensor(33.),
#  tensor(18.),
#  tensor(20.),
#  tensor(23.),
#  tensor(44.),
#  tensor(32.),
#  tensor(12.),
#  tensor(21.),
#  tensor(22.),
#  tensor(24.),
#  tensor(12.),
#  tensor(15.),
#  tensor(9.),
#  tensor(13.),
#  tensor(49.),
#  tensor(19.),
#  tensor(15.),
#  tensor(23.),
#  tensor(15.),
#  tensor(28.),
#  tensor(21.),
#  tensor(16.),
#  tensor(15.),
#  tensor(32.),
#  tensor(14.),
#  tensor(22.),
#  tensor(14.),
#  tensor(22.),
#  tensor(13.),
#  tensor(12.),
#  tensor(25.),
#  tensor(15.),
#  tensor(13.),
#  tensor(12.),
#  tensor(46.),
#  tensor(14.),
#  tensor(15.),
#  tensor(27.),
#  tensor(30.),
#  tensor(11.),
#  tensor(21.),
#  tensor(66.),
#  tensor(10.),
#  tensor(26.),
#  tensor(22.),
#  tensor(10.),
#  tensor(35.),
#  tensor(21.),
#  tensor(43.),
#  tensor(20.),
#  tensor(14.),
#  tensor(15.),
#  tensor(8.),
#  tensor(15.),
#  tensor(25.),
#  tensor(9.),
#  tensor(17.),
#  tensor(21.),
#  tensor(33.),
#  tensor(25.),
#  tensor(13.),
#  tensor(34.),
#  tensor(22.),
#  tensor(12.),
#  tensor(14.),
#  tensor(15.),
#  tensor(17.),
#  tensor(10.),
#  tensor(26.),
#  tensor(13.),
#  tensor(11.),
#  tensor(14.),
#  tensor(19.),
#  tensor(15.),
#  tensor(11.),
#  tensor(26.),
#  tensor(19.),
#  tensor(25.),
#  tensor(14.),
#  tensor(13.),
#  tensor(16.),
#  tensor(14.),
#  tensor(9.),
#  tensor(12.),
#  tensor(30.),
#  tensor(11.),
#  tensor(17.),
#  tensor(18.),
#  tensor(16.),
#  tensor(10.),
#  tensor(14.),
#  tensor(12.),
#  tensor(10.),
#  tensor(38.),
#  tensor(15.),
#  tensor(19.),
#  tensor(13.),
#  tensor(27.),
#  tensor(16.),
#  tensor(15.),
#  tensor(11.),
#  tensor(12.),
#  tensor(11.),
#  tensor(15.),
#  tensor(12.),
#  tensor(21.),
#  tensor(11.),
#  tensor(20.),
#  tensor(9.),
#  tensor(13.),
#  tensor(15.),
#  tensor(27.),
#  tensor(19.),
#  tensor(13.),
#  tensor(56.),
#  tensor(28.),
#  tensor(11.),
#  tensor(32.),
#  tensor(36.),
#  tensor(30.),
#  tensor(16.),
#  tensor(37.),
#  tensor(11.),
#  tensor(18.),
#  tensor(29.),
#  tensor(15.),
#  tensor(9.),
#  tensor(17.),
#  tensor(11.),
#  tensor(22.),
#  tensor(12.),
#  tensor(21.),
#  tensor(9.),
#  tensor(52.),
#  tensor(11.),
#  tensor(20.),
#  tensor(14.),
#  tensor(13.),
#  tensor(9.),
#  tensor(12.),
#  tensor(17.),
#  tensor(14.),
#  tensor(10.),
#  tensor(9.),
#  tensor(13.),
#  tensor(17.),
#  tensor(16.),
#  tensor(14.),
#  tensor(17.),
#  tensor(11.),
#  tensor(24.),
#  tensor(10.),
#  tensor(20.),
#  tensor(22.),
#  tensor(31.),
#  tensor(23.),
#  tensor(10.),
#  tensor(14.),
#  tensor(19.),
#  tensor(20.),
#  tensor(10.),
#  tensor(23.),
#  tensor(17.),
#  tensor(12.),
#  tensor(12.),
#  tensor(21.),
#  tensor(19.),
#  tensor(10.),
#  tensor(17.),
#  tensor(13.),
#  tensor(25.),
#  tensor(16.),
#  tensor(15.),
#  tensor(15.),
#  tensor(23.),
#  tensor(12.),
#  tensor(11.),
#  tensor(9.),
#  tensor(12.),
#  tensor(11.),
#  tensor(38.),
#  tensor(26.),
#  tensor(14.),
#  tensor(12.),
#  tensor(12.),
#  tensor(12.),
#  tensor(10.),
#  tensor(10.),
#  tensor(10.),
#  tensor(17.),
#  tensor(10.),
#  tensor(17.),
#  tensor(12.),
#  tensor(11.),
#  tensor(11.),
#  tensor(11.),
#  tensor(16.),
#  tensor(16.),
#  tensor(13.),
#  tensor(23.),
#  tensor(13.),
#  tensor(14.),
#  tensor(18.),
#  tensor(10.),
#  tensor(16.),
#  tensor(16.),
#  tensor(16.),
#  tensor(18.),
#  tensor(9.),
#  tensor(10.),
#  tensor(10.),
#  tensor(15.),
#  tensor(21.),
#  tensor(12.),
#  tensor(18.),
#  tensor(14.),
#  tensor(14.),
#  tensor(30.),
#  tensor(27.),
#  tensor(9.),
#  tensor(9.),
#  tensor(23.),
#  tensor(37.),
#  tensor(15.),
#  tensor(13.),
#  tensor(18.),
#  tensor(15.),
#  tensor(9.),
#  tensor(15.),
#  tensor(10.),
#  tensor(12.),
#  tensor(23.),
#  tensor(10.),
#  tensor(15.),
#  tensor(14.),
#  tensor(12.),
#  tensor(17.),
#  tensor(14.),
#  tensor(13.),
#  tensor(12.),
#  tensor(10.),
#  tensor(12.),
#  tensor(15.),
#  tensor(11.),
#  tensor(32.),
#  tensor(14.),
#  tensor(11.),
#  tensor(20.),
#  tensor(12.),
#  tensor(15.),
#  tensor(15.),
#  tensor(12.),
#  tensor(12.),
#  tensor(10.),
#  tensor(20.),
#  tensor(10.),
#  tensor(21.),
#  tensor(12.),
#  tensor(12.),
#  tensor(13.),
#  tensor(13.),
#  tensor(15.),
#  tensor(16.),
#  tensor(12.),
#  tensor(15.),
#  tensor(10.),
#  tensor(22.),
#  tensor(21.),
#  tensor(10.),
#  tensor(14.),
#  tensor(11.),
#  tensor(29.),
#  tensor(9.),
#  tensor(10.),
#  tensor(11.),
#  tensor(21.),
#  tensor(17.),
#  tensor(12.),
#  tensor(13.),
#  tensor(8.),
#  tensor(11.),
#  tensor(10.),
#  tensor(11.),
#  tensor(15.),
#  tensor(21.),
#  tensor(11.),
#  tensor(16.),
#  tensor(18.),
#  tensor(19.),
#  tensor(9.),
#  tensor(13.),
#  tensor(12.),
#  tensor(24.),
#  tensor(14.),
#  tensor(20.),
#  tensor(9.),
#  tensor(21.),
#  tensor(11.),
#  tensor(13.),
#  tensor(8.),
#  tensor(14.),
#  tensor(13.),
#  tensor(12.),
#  tensor(12.),
#  tensor(15.),
#  tensor(13.),
#  tensor(10.),
#  tensor(12.),
#  tensor(13.),
#  tensor(10.),
#  tensor(11.),
#  tensor(10.),
#  tensor(12.),
#  tensor(10.),
#  tensor(11.),
#  tensor(16.),
#  tensor(14.),
#  tensor(14.),
#  tensor(22.),
#  tensor(10.),
#  tensor(9.),
#  tensor(10.),
#  tensor(9.),
#  tensor(11.),
#  tensor(13.),
#  tensor(14.),
#  tensor(9.),
#  tensor(9.),
#  tensor(10.),
#  tensor(16.),
#  tensor(10.),
#  tensor(11.),
#  tensor(12.),
#  tensor(11.),
#  tensor(10.),
#  tensor(15.),
#  tensor(14.),
#  tensor(10.),
#  tensor(23.),
#  tensor(15.),
#  tensor(16.),
#  tensor(19.),
#  tensor(14.),
#  tensor(13.),
#  tensor(27.),
#  tensor(15.),
#  tensor(17.),
#  tensor(12.),
#  tensor(8.),
#  tensor(15.),
#  tensor(14.),
#  tensor(8.),
#  tensor(18.),
#  tensor(12.),
#  tensor(10.),
#  tensor(9.),
#  tensor(28.),
#  tensor(14.),
#  tensor(14.),
#  tensor(26.),
#  tensor(11.),
#  tensor(12.),
#  tensor(8.),
#  tensor(12.),
#  tensor(11.),
#  tensor(10.),
#  tensor(8.),
#  tensor(12.),
#  tensor(14.),
#  tensor(16.),
#  tensor(10.),
#  tensor(14.),
#  tensor(15.),
#  tensor(12.),
#  tensor(12.),
#  tensor(16.),
#  tensor(9.),
#  tensor(13.),
#  tensor(17.),
#  tensor(11.),
#  tensor(14.),
#  tensor(14.),
#  tensor(15.),
#  tensor(13.),
#  tensor(13.),
#  tensor(12.),
#  tensor(15.),
#  tensor(14.),
#  tensor(13.),
#  tensor(10.),
#  tensor(15.),
#  tensor(11.),
#  tensor(10.),
#  tensor(21.),
#  tensor(12.),
#  tensor(11.),
#  tensor(11.),
#  tensor(19.),
#  tensor(12.),
#  tensor(13.),
#  tensor(15.),
#  tensor(13.),
#  tensor(12.),
#  tensor(24.),
#  tensor(9.),
#  tensor(20.),
#  tensor(17.),
#  tensor(12.),
#  tensor(14.),
#  tensor(21.),
#  tensor(13.),
#  tensor(18.),
#  tensor(11.),
#  tensor(31.),
#  tensor(25.),
#  tensor(39.),
#  tensor(16.),
#  tensor(23.),
#  tensor(10.),
#  tensor(9.),
#  tensor(11.),
#  tensor(13.),
#  tensor(9.),
#  tensor(15.),
#  tensor(18.),
#  tensor(18.),
#  tensor(10.),
#  tensor(25.),
#  tensor(18.),
#  tensor(12.),
#  tensor(12.),
#  tensor(11.),
#  tensor(10.),
#  tensor(22.),
#  tensor(18.),
#  tensor(14.),
#  tensor(12.),
#  tensor(9.),
#  tensor(8.),
#  tensor(13.),
#  tensor(16.),
#  tensor(16.),
#  tensor(17.),
#  tensor(21.),
#  tensor(13.),
#  tensor(11.),
#  tensor(12.),
#  tensor(15.),
#  tensor(13.),
#  tensor(25.),
#  tensor(15.),
#  tensor(14.),
#  tensor(17.),
#  tensor(12.),
#  tensor(19.),
#  tensor(11.),
#  tensor(12.),
#  tensor(12.),
#  tensor(16.),
#  tensor(10.),
#  tensor(12.),
#  tensor(22.),
#  tensor(9.),
#  tensor(12.),
#  tensor(14.),
#  tensor(12.),
#  tensor(18.),
#  tensor(11.),
#  tensor(15.),
#  tensor(8.),
#  tensor(11.),
#  tensor(24.),
#  tensor(18.),
#  tensor(15.),
#  tensor(16.),
#  tensor(19.),
#  tensor(26.),
#  tensor(13.),
#  tensor(9.),
#  tensor(27.),
#  tensor(14.),
#  tensor(19.),
#  tensor(12.),
#  tensor(12.),
#  tensor(14.),
#  tensor(15.),
#  tensor(15.),
#  tensor(21.),
#  tensor(13.),
#  tensor(12.),
#  tensor(12.),
#  tensor(17.),
#  tensor(13.),
#  tensor(20.),
#  tensor(16.),
#  tensor(12.),
#  tensor(8.),
#  tensor(11.),
#  tensor(14.),
#  tensor(13.),
#  tensor(17.),
#  tensor(12.),
#  tensor(13.),
#  tensor(15.),
#  tensor(10.),
#  tensor(10.),
#  tensor(15.),
#  tensor(12.),
#  tensor(11.),
#  tensor(15.),
#  tensor(11.),
#  tensor(11.),
#  tensor(20.),
#  tensor(8.),
#  tensor(8.),
#  tensor(12.),
#  tensor(17.),
#  tensor(12.),
#  tensor(14.),
#  tensor(11.),
#  tensor(10.),
#  tensor(9.),
#  tensor(10.),
#  tensor(20.),
#  tensor(13.),
#  tensor(12.),
#  tensor(17.),
#  tensor(15.),
#  tensor(14.),
#  tensor(12.),
#  tensor(19.),
#  tensor(9.),
#  tensor(21.),
#  tensor(14.),
#  tensor(10.),
#  tensor(15.),
#  tensor(10.),
#  tensor(12.),
#  tensor(13.),
#  tensor(21.),
#  tensor(19.),
#  tensor(10.),
#  tensor(19.),
#  tensor(10.),
#  tensor(13.),
#  tensor(16.),
#  tensor(14.),
#  tensor(10.),
#  tensor(11.),
#  tensor(11.),
#  tensor(10.),
#  tensor(10.),
#  tensor(12.),
#  tensor(11.),
#  tensor(10.),
#  tensor(12.),
#  tensor(12.),
#  tensor(10.),
#  tensor(8.),
#  tensor(9.),
#  tensor(9.),
#  tensor(11.),
#  tensor(8.),
#  tensor(9.),
#  tensor(12.),
#  tensor(9.),
#  tensor(10.),
#  tensor(17.),
#  tensor(10.),
#  tensor(8.),
#  tensor(15.),
#  tensor(8.),
#  tensor(12.),
#  tensor(12.),
#  tensor(9.),
#  tensor(11.),
#  tensor(10.),
#  tensor(9.),
#  tensor(34.),
#  tensor(31.),
#  tensor(8.),
#  tensor(21.),
#  tensor(21.),
#  tensor(30.),
#  tensor(16.),
#  tensor(9.),
#  tensor(9.),
#  tensor(9.),
#  tensor(10.),
#  tensor(15.),
#  tensor(17.),
#  tensor(12.),
#  tensor(11.),
#  tensor(18.),
#  tensor(13.),
#  tensor(20.),
#  tensor(31.),
#  tensor(12.),
#  tensor(9.),
#  tensor(15.),
#  tensor(29.),
#  tensor(13.),
#  tensor(11.),
#  tensor(15.),
#  tensor(11.),
#  tensor(12.),
#  tensor(25.),
#  tensor(20.),
#  tensor(17.),
#  tensor(10.),
#  tensor(16.),
#  tensor(12.),
#  tensor(13.),
#  tensor(11.),
#  tensor(16.),
#  tensor(10.),
#  tensor(12.),
#  tensor(10.),
#  tensor(11.),
#  tensor(12.),
#  tensor(12.),
#  tensor(12.),
#  tensor(13.),
#  tensor(9.),
#  tensor(9.),
#  tensor(10.),
#  tensor(26.),
#  tensor(11.),
#  tensor(13.),
#  tensor(10.),
#  tensor(12.),
#  ...]

# %%
import numpy as np

np.array(episode_rewards).mean()
# Out:
# 14.4351

# %%
from typing import List

import torch
from torch import nn
from torch import optim
from torch.distributions import Categorical
import gym

from octopus.policy.reward import calculate_discounted_return_each_timestep, calculate_advantages

# %%
import wandb

# %%
import wandb
import time

run_name = f"{gym_id}__{exp_name}__{seed}__{int(time.time())}"

# %%
gym_id = "CartPole-v1"
exp_name = "A2C"
seed = 42

# %%
import wandb
import time

run_name = f"{gym_id}__{exp_name}__{seed}__{int(time.time())}"

# %%
run_name
# Out:
# 'CartPole-v1__A2C__42__1671857230'

# %%
import wandb
import time

run_name = f"{gym_id}__{exp_name}__{seed}__{int(time.time())}"

# %%
run_name
# Out:
# 'CartPole-v1__A2C__42__1671857240'

# %%
import wandb
import time

run_name = f"{gym_id}__{exp_name}__{seed}__{int(time.time())}"

# %%
run_name
# Out:
# 'CartPole-v1__A2C__42__1671857243'

# %%
import wandb
import time

run_name = f"{gym_id}__{exp_name}__{seed}__{int(time.time())}"

wandb.init(
    # project=args.wandb_project_name,
    # entity=args.wandb_entity,
    sync_tensorboard=True,
    # config=vars(args),
    name=run_name,
    monitor_gym=True,
    save_code=True,
)

# %%
from typing import List

import torch
from torch import nn
from torch import optim
from torch.distributions import Categorical
import gym

from octopus.policy.reward import calculate_discounted_return_each_timestep, calculate_advantages

# %%
class ActorNet(nn.Module):
    def __init__(self, n_observations, n_actions, hidden_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_observations, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions),
            nn.Softmax(dim=-1)
        )
    
    def forward(self, state):
        return self.layers(state)

# %%
class CriticNet(nn.Module):
    def __init__(self, n_observations, n_actions, hidden_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_observations, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 1)
        )
    
    def forward(self, state):
        return self.layers(state)

# %%
# class A2C(nn.Module):
#     def __init__(self, n_observations, n_actions, hidden_size):
#         super().__init__()
#         self.actor = nn.Sequential(
#             nn.Linear(n_observations, hidden_size),
#             nn.ReLU(),
#             nn.Linear(hidden_size, n_actions),
#             nn.Softmax(dim=-1)
#         )
        
#         self.critic = nn.Sequential(
#             nn.Linear(n_observations, hidden_size),
#             nn.ReLU(),
#             nn.Linear(hidden_size, 1)
#         )
    
#     def forward(self, state):
#         pred_action = self.actor(state)
#         pred_value = self.critic(state)
        
#         return pred_action, pred_value

# %%
gym_id = "CartPole-v1"
exp_name = "A2C"
seed = 42

# %%
import wandb
import time

run_name = f"{gym_id}__{exp_name}__{seed}__{int(time.time())}"

wandb.init(
    # project=args.wandb_project_name,
    # entity=args.wandb_entity,
    sync_tensorboard=True,
    # config=vars(args),
    name=run_name,
    monitor_gym=True,
    save_code=True,
)
# Out:
# <wandb.sdk.wandb_run.Run at 0x17fd8d760>

# %%
from typing import List

import torch
from torch import nn
from torch import optim
from torch.distributions import Categorical
import gym

from octopus.policy.reward import calculate_discounted_return_each_timestep, calculate_advantages

# %%
class ActorNet(nn.Module):
    def __init__(self, n_observations, n_actions, hidden_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_observations, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions),
            nn.Softmax(dim=-1)
        )
    
    def forward(self, state):
        return self.layers(state)

# %%
class CriticNet(nn.Module):
    def __init__(self, n_observations, n_actions, hidden_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_observations, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 1)
        )
    
    def forward(self, state):
        return self.layers(state)

# %%
gym_id = "CartPole-v1"
exp_name = "A2C"
seed = 42

# %%
import wandb
import time

run_name = f"{gym_id}__{exp_name}__{seed}__{int(time.time())}"

wandb.init(
    # project=args.wandb_project_name,
    # entity=args.wandb_entity,
    sync_tensorboard=True,
    # config=vars(args),
    name=run_name,
    monitor_gym=True,
    save_code=True,
)
# Out:
# <wandb.sdk.wandb_run.Run at 0x17ff20a30>

# %%
run_name
# Out:
# 'CartPole-v1__A2C__42__1671857634'

# %%
env = gym.make(gym_id)

# %%
n_observations = env.observation_space.shape[0]
n_actions = env.action_space.n

actor = ActorNet(n_observations, n_actions, hidden_size=128)
critic = CriticNet(n_observations, n_actions, hidden_size=128)

LEARNING_RATE = 0.001

actor_optim = optim.Adam(actor.parameters(), lr=LEARNING_RATE)
critic_optim = optim.Adam(critic.parameters(), lr=LEARNING_RATE)
    
critic_loss_func = nn.MSELoss()

# %%
def compute_actor_loss(log_probs: List[torch.Tensor], advantages: List[torch.Tensor]):
    """Calculate the advantage loss for actor

    Args:
        log_probs (_type_): a list of 
        advantages (_type_): _description_

    Returns:
        _type_: _description_
    """
    assert len(log_probs) == len(advantages)
    
    total_loss = 0
    for log_prob, advantage in zip(log_probs, advantages):
        total_loss = log_prob * advantage
    
    # return -(torch.sum(log_probs * advantages))
    return -total_loss

# %%
N_EPISODES = 10000
DISCOUNT_FACTOR = 0.99

episode_rewards = []
episode_actor_losses = []
episode_critic_losses = []

for episode in range(N_EPISODES):
    
    pred_log_probs = []
    pred_q_values = []
    rewards = []
    total_reward = 0

    observation, _ = env.reset()
    observation = torch.from_numpy(observation)
    in_progress = True
    
    while in_progress:
        pred_action = actor(observation)
        pred_value = critic(observation)

        action_idx = Categorical(pred_action).sample().item()
                        
        new_observation, reward, done, truncated, info = env.step(action_idx)
        reward = torch.tensor(reward)
        
        pred_log_probs.append(pred_action[action_idx].log())
        pred_q_values.append(pred_value)
        rewards.append(reward)
        total_reward += reward
        
        if done: break
        
    # TODO: this one make it loss grad
    # pred_q_values = torch.tensor(pred_q_values)
    
    discounted_returns = calculate_discounted_return_each_timestep(rewards, DISCOUNT_FACTOR)
    advantages = calculate_advantages(discounted_returns, torch.tensor(pred_q_values))
    loss_actor = compute_actor_loss(pred_log_probs, advantages)
    
    _pred_q_values = torch.tensor(pred_q_values)
    _pred_q_values.requires_grad = True
    loss_critic = critic_loss_func(discounted_returns, _pred_q_values)
    
    episode_actor_losses.append(loss_actor.detach().numpy())
    episode_critic_losses.append(loss_critic.detach().numpy())
    episode_rewards.append(total_reward)
    
    wandb.log({
        "actor_losses": loss_actor.detach().numpy(),
        "critic_losses": loss_critic.detach().numpy(),
        "rewards": total_reward
    })

    
    actor_optim.zero_grad()
    critic_optim.zero_grad()
    
    loss_actor.backward()
    loss_critic.backward()
    
    actor_optim.step()
    critic_optim.step()
    
    print(f"episode={episode} loss_actor={loss_actor}, loss_critic={loss_critic}")

# %%
from typing import List

import torch
from torch import nn
from torch import optim
from torch.distributions import Categorical
import gym

from octopus.policy.reward import calculate_discounted_return_each_timestep, calculate_advantages

# %%
class ActorNet(nn.Module):
    def __init__(self, n_observations, n_actions, hidden_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_observations, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions),
            nn.Softmax(dim=-1)
        )
    
    def forward(self, state):
        return self.layers(state)

# %%
class CriticNet(nn.Module):
    def __init__(self, n_observations, n_actions, hidden_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_observations, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 1)
        )
    
    def forward(self, state):
        return self.layers(state)

# %%
# class A2C(nn.Module):
#     def __init__(self, n_observations, n_actions, hidden_size):
#         super().__init__()
#         self.actor = nn.Sequential(
#             nn.Linear(n_observations, hidden_size),
#             nn.ReLU(),
#             nn.Linear(hidden_size, n_actions),
#             nn.Softmax(dim=-1)
#         )
        
#         self.critic = nn.Sequential(
#             nn.Linear(n_observations, hidden_size),
#             nn.ReLU(),
#             nn.Linear(hidden_size, 1)
#         )
    
#     def forward(self, state):
#         pred_action = self.actor(state)
#         pred_value = self.critic(state)
        
#         return pred_action, pred_value

# %%
gym_id = "CartPole-v1"
exp_name = "A2C"
seed = 42

# %%
import wandb
import time

run_name = f"{gym_id}__{exp_name}__{seed}__{int(time.time())}"

wandb.init(
    # project=args.wandb_project_name,
    # entity=args.wandb_entity,
    sync_tensorboard=True,
    # config=vars(args),
    name=run_name,
    monitor_gym=True,
    save_code=True,
)
# Out:
# <wandb.sdk.wandb_run.Run at 0x123349c70>
# Finishing last run (ID:35is3wp0) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.013 MB of 0.013 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>actor_losses</td><td>▆▃▃▃▄▆▄▄▃▃▇▃▃█▂█▃▇▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>critic_losses</td><td>▁▆▁▆▃▄▁▂▁▂▁▂▂▃▁█▅▁▂▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>rewards</td><td>▁▆▁▆▃▅▂▂▂▃▁▃▂▄▁█▅▁▂▁▁▁▂▁▂▂▁▂▁▂▂▁▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>actor_losses</td><td>0.00014</td></tr><tr><td>critic_losses</td><td>35.15531</td></tr><tr><td>rewards</td><td>10.0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">CartPole-v1__A2C__42__1671857634</strong>: <a href="https://wandb.ai/xariusdrake/reinforcement-learning-examples/runs/35is3wp0" target="_blank">https://wandb.ai/xariusdrake/reinforcement-learning-examples/runs/35is3wp0</a><br/>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221224_115354-35is3wp0/logs</code>
# Successfully finished last run (ID:35is3wp0). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01669809861666636, max=1.0)…
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/Users/education/DATA/projects/ai/reinforcement-learning/reinforcement-learning/examples/wandb/run-20221224_115850-38nipm0r</code>
# Syncing run <strong><a href="https://wandb.ai/xariusdrake/reinforcement-learning-examples/runs/38nipm0r" target="_blank">CartPole-v1__A2C__42__1671857930</a></strong> to <a href="https://wandb.ai/xariusdrake/reinforcement-learning-examples" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
run_name
# Out:
# 'CartPole-v1__A2C__42__1671857930'

# %%
env = gym.make(gym_id)

# %%
n_observations = env.observation_space.shape[0]
n_actions = env.action_space.n

actor = ActorNet(n_observations, n_actions, hidden_size=128)
critic = CriticNet(n_observations, n_actions, hidden_size=128)

LEARNING_RATE = 0.001

actor_optim = optim.Adam(actor.parameters(), lr=LEARNING_RATE)
critic_optim = optim.Adam(critic.parameters(), lr=LEARNING_RATE)
    
critic_loss_func = nn.MSELoss()

# %%
def compute_actor_loss(log_probs: List[torch.Tensor], advantages: List[torch.Tensor]):
    """Calculate the advantage loss for actor

    Args:
        log_probs (_type_): a list of 
        advantages (_type_): _description_

    Returns:
        _type_: _description_
    """
    assert len(log_probs) == len(advantages)
    
    total_loss = 0
    for log_prob, advantage in zip(log_probs, advantages):
        total_loss = log_prob * advantage
    
    # return -(torch.sum(log_probs * advantages))
    return -total_loss

# %%
N_EPISODES = 10000
DISCOUNT_FACTOR = 0.99

episode_rewards = []
episode_actor_losses = []
episode_critic_losses = []

for episode in range(N_EPISODES):
    
    pred_log_probs = []
    pred_q_values = []
    rewards = []
    total_reward = 0

    observation, _ = env.reset()
    observation = torch.from_numpy(observation)
    in_progress = True
    
    while in_progress:
        pred_action = actor(observation)
        pred_value = critic(observation)

        action_idx = Categorical(pred_action).sample().item()
                        
        new_observation, reward, done, truncated, info = env.step(action_idx)
        reward = torch.tensor(reward)
        
        pred_log_probs.append(pred_action[action_idx].log())
        pred_q_values.append(pred_value)
        rewards.append(reward)
        total_reward += reward
        
        if done: break
        
    # TODO: this one make it loss grad
    # pred_q_values = torch.tensor(pred_q_values)
    
    discounted_returns = calculate_discounted_return_each_timestep(rewards, DISCOUNT_FACTOR)
    advantages = calculate_advantages(discounted_returns, torch.tensor(pred_q_values))
    loss_actor = compute_actor_loss(pred_log_probs, advantages)
    
    _pred_q_values = torch.tensor(pred_q_values)
    _pred_q_values.requires_grad = True
    loss_critic = critic_loss_func(discounted_returns, _pred_q_values)
    
    episode_actor_losses.append(loss_actor.detach().numpy())
    episode_critic_losses.append(loss_critic.detach().numpy())
    episode_rewards.append(total_reward)
    
    wandb.log({
        "actor_losses": loss_actor.detach().numpy(),
        "critic_losses": loss_critic.detach().numpy(),
        "rewards": total_reward
    })

    
    actor_optim.zero_grad()
    critic_optim.zero_grad()
    
    loss_actor.backward()
    loss_critic.backward()
    
    actor_optim.step()
    critic_optim.step()
    
    print(f"episode={episode} loss_actor={loss_actor}, loss_critic={loss_critic}")

# %%
from typing import List

import torch
from torch import nn
from torch import optim
from torch.distributions import Categorical
import gym

from octopus.policy.reward import calculate_discounted_return_each_timestep, calculate_advantages

# %%
class ActorNet(nn.Module):
    def __init__(self, n_observations, n_actions, hidden_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_observations, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions),
            nn.Softmax(dim=-1)
        )
    
    def forward(self, state):
        return self.layers(state)

# %%
class CriticNet(nn.Module):
    def __init__(self, n_observations, n_actions, hidden_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_observations, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 1)
        )
    
    def forward(self, state):
        return self.layers(state)

# %%
# class A2C(nn.Module):
#     def __init__(self, n_observations, n_actions, hidden_size):
#         super().__init__()
#         self.actor = nn.Sequential(
#             nn.Linear(n_observations, hidden_size),
#             nn.ReLU(),
#             nn.Linear(hidden_size, n_actions),
#             nn.Softmax(dim=-1)
#         )
        
#         self.critic = nn.Sequential(
#             nn.Linear(n_observations, hidden_size),
#             nn.ReLU(),
#             nn.Linear(hidden_size, 1)
#         )
    
#     def forward(self, state):
#         pred_action = self.actor(state)
#         pred_value = self.critic(state)
        
#         return pred_action, pred_value

# %%
gym_id = "CartPole-v1"
exp_name = "A2C"
seed = 42

# %%
import wandb
import time

run_name = f"{gym_id}__{exp_name}__{seed}__{int(time.time())}"

wandb.init(
    project="simple_a2c",
    # entity=args.wandb_entity,
    sync_tensorboard=True,
    # config=vars(args),
    name=run_name,
    monitor_gym=True,
    save_code=True,
)
