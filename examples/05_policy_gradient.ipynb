# %%
import torch
from torch import nn
from torch import optim

import gym
import numpy as np

from octopus.policy.evaluate import evaluate_agent
from octopus.policy.loss import reinforce_loss

# %%
class Policy(nn.Module):
    def __init__(self, n_states, n_hidden, n_actions):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_states, n_hidden),
            nn.ReLU(),
            # nn.Linear(n_hidden, n_hidden),
            # nn.ReLU(),
            nn.Linear(n_hidden, n_actions),
            nn.Softmax(dim=-1)
        )
    
    def forward(self, x):
        return self.layers(x)

# %%
env = gym.make("CartPole-v1")
n_states = env.observation_space.shape[0]
n_actions = env.action_space.n
n_hidden = 64

# %%
# def reinforce(policy, optimizier, n_training_episodes, gamma=0.99):
#     for i_episode in range(n_training_episodes):
#         rewards = []
#         selected_actions = []
#         log_prob_selected_actions = []
        
#         state, _ = env.reset()
#         state = torch.from_numpy(state)
#         in_progress = True
        
#         while in_progress:
#             predicted_action = policy(state)
#             action = torch.multinomial(predicted_action, num_samples=1).item()
            
#             next_state, reward, done, truncated, info = env.step(action)
            
#             selected_actions.append(action)
#             log_prob_selected_actions.append(predicted_action[action].log())
#             rewards.append(reward)
            
#             if done: break
            
#             state = torch.from_numpy(next_state)

#         # [1.0, 0.99, 0.9801, 0.970299, 0.96059601,...]
#         discounts = [gamma**k for k in range(len(rewards)+1)]
        
#         # [1.0, 0.99, 0.9801, 0.970299, 0.96059601,..] for each reward equals to 1
#         discounted_rewards = [discount*reward for discount, reward in zip(discounts, rewards)]

#         # a scalar
#         discounted_return = sum(discounted_rewards)
        
#         # calculate discounted return at each time step
#         discounted_return_each_step = []
#         g_value = 0
#         for discounted_reward_each_step in reversed(discounted_rewards):
#             g_value += discounted_reward_each_step
#             discounted_return_each_step.append(g_value)
        
#         discounted_return_each_step = discounted_return_each_step[::-1]
        
#         losses = []
#         for log_prob, g_step in zip(log_prob_selected_actions, discounted_return_each_step):
#             # why not discounted_return at each timestep corresponds to log_pro
#             losses.append(-log_prob * g_step)
        
#         # losses = []
#         # for log_prob in log_prob_selected_actions:
#         #     # why not discounted_return at each timestep corresponds to log_pro
#         #     losses.append(-log_prob * discounted_return)
        
#         loss = sum(losses)
#         optimizier.zero_grad()
#         loss.backward()
#         optimizier.step()
                
#         print('Episode {}\tAverage Score: {:.2f}'.format(i_episode, loss.detach().numpy()))

# %%
# class Learner:
#     def __init__(self, model):
#         self.model = model
#         self.optimizier = optim.Adam(model.parameters(), 1e-3)

# %%
def learner(policy, optimizier, n_training_episodes, discount_factor=0.99):
    for i_episode in range(n_training_episodes):
        rewards = []
        selected_actions = []
        log_prob_selected_actions = []
        selected_probs = []
        
        state, _ = env.reset()
        state = torch.from_numpy(state)
        in_progress = True
        
        while in_progress:
            predicted_action = policy(state)
            action = torch.multinomial(predicted_action, num_samples=1).item()
            
            next_state, reward, done, truncated, info = env.step(action)
            
            selected_actions.append(action)
            log_prob_selected_actions.append(predicted_action[action].log())
            selected_probs.append(predicted_action[action])
            rewards.append(torch.tensor(reward))
            
            if done: break
            
            state = torch.from_numpy(next_state)

        loss = reinforce_loss(
            log_probs=log_prob_selected_actions,
            rewards=rewards,
            discount_factor=discount_factor
        )
        
        optimizier.zero_grad()
        loss.backward()
        optimizier.step()
                
        print('Episode {}\tLoss: {:.2f}'.format(i_episode, loss.detach().numpy()))

# %%
model = Policy(n_states, n_hidden, n_actions)
optimizier = optim.Adam(model.parameters(), lr=1e-2)

learner(model, optimizier, n_training_episodes=500)
# Out:
# Episode 0	Average Score: 5.82
# Episode 1	Average Score: 10.81
# Episode 2	Average Score: 14.04
# Episode 3	Average Score: 12.20
# Episode 4	Average Score: 5.73
# Episode 5	Average Score: 7.16
# Episode 6	Average Score: 9.45
# Episode 7	Average Score: 14.82
# Episode 8	Average Score: 6.54
# Episode 9	Average Score: 20.86
# Episode 10	Average Score: 8.44
# Episode 11	Average Score: 6.08
# Episode 12	Average Score: 21.25
# Episode 13	Average Score: 9.49
# Episode 14	Average Score: 7.99
# Episode 15	Average Score: 9.28
# Episode 16	Average Score: 6.89
# Episode 17	Average Score: 14.57
# Episode 18	Average Score: 9.51
# Episode 19	Average Score: 6.68
# Episode 20	Average Score: 17.42
# Episode 21	Average Score: 25.53
# Episode 22	Average Score: 16.06
# Episode 23	Average Score: 11.77
# Episode 24	Average Score: 5.59
# Episode 25	Average Score: 10.56
# Episode 26	Average Score: 9.92
# Episode 27	Average Score: 18.46
# Episode 28	Average Score: 10.76
# Episode 29	Average Score: 13.68
# Episode 30	Average Score: 11.45
# Episode 31	Average Score: 16.70
# Episode 32	Average Score: 21.02
# Episode 33	Average Score: 16.48
# Episode 34	Average Score: 17.07
# Episode 35	Average Score: 12.44
# Episode 36	Average Score: 12.24
# Episode 37	Average Score: 13.20
# Episode 38	Average Score: 18.45
# Episode 39	Average Score: 12.48
# Episode 40	Average Score: 10.00
# Episode 41	Average Score: 13.28
# Episode 42	Average Score: 16.17
# Episode 43	Average Score: 5.68
# Episode 44	Average Score: 12.52
# Episode 45	Average Score: 13.04
# Episode 46	Average Score: 17.28
# Episode 47	Average Score: 18.36
# Episode 48	Average Score: 6.46
# Episode 49	Average Score: 14.13
# Episode 50	Average Score: 14.45
# Episode 51	Average Score: 29.48
# Episode 52	Average Score: 20.37
# Episode 53	Average Score: 20.63
# Episode 54	Average Score: 25.07
# Episode 55	Average Score: 12.32
# Episode 56	Average Score: 17.72
# Episode 57	Average Score: 8.19
# Episode 58	Average Score: 25.60
# Episode 59	Average Score: 9.39
# Episode 60	Average Score: 19.34
# Episode 61	Average Score: 7.38
# Episode 62	Average Score: 6.88
# Episode 63	Average Score: 14.92
# Episode 64	Average Score: 15.74
# Episode 65	Average Score: 7.02
# Episode 66	Average Score: 8.10
# Episode 67	Average Score: 12.76
# Episode 68	Average Score: 6.56
# Episode 69	Average Score: 7.35
# Episode 70	Average Score: 9.79
# Episode 71	Average Score: 5.88
# Episode 72	Average Score: 7.64
# Episode 73	Average Score: 8.61
# Episode 74	Average Score: 7.10
# Episode 75	Average Score: 13.96
# Episode 76	Average Score: 7.44
# Episode 77	Average Score: 9.01
# Episode 78	Average Score: 10.10
# Episode 79	Average Score: 11.33
# Episode 80	Average Score: 13.25
# Episode 81	Average Score: 17.09
# Episode 82	Average Score: 7.86
# Episode 83	Average Score: 9.62
# Episode 84	Average Score: 6.96
# Episode 85	Average Score: 6.25
# Episode 86	Average Score: 16.26
# Episode 87	Average Score: 12.90
# Episode 88	Average Score: 6.98
# Episode 89	Average Score: 21.84
# Episode 90	Average Score: 15.05
# Episode 91	Average Score: 8.74
# Episode 92	Average Score: 8.71
# Episode 93	Average Score: 7.84
# Episode 94	Average Score: 16.23
# Episode 95	Average Score: 11.71
# Episode 96	Average Score: 13.86
# Episode 97	Average Score: 19.70
# Episode 98	Average Score: 18.88
# Episode 99	Average Score: 22.21

# %%
# def reinforce(policy, optimizier, n_training_episodes, gamma=0.99):
#     for i_episode in range(n_training_episodes):
#         rewards = []
#         selected_actions = []
#         log_prob_selected_actions = []
        
#         state, _ = env.reset()
#         state = torch.from_numpy(state)
#         in_progress = True
        
#         while in_progress:
#             predicted_action = policy(state)
#             action = torch.multinomial(predicted_action, num_samples=1).item()
            
#             next_state, reward, done, truncated, info = env.step(action)
            
#             selected_actions.append(action)
#             log_prob_selected_actions.append(predicted_action[action].log())
#             rewards.append(reward)
            
#             if done: break
            
#             state = torch.from_numpy(next_state)

#         # [1.0, 0.99, 0.9801, 0.970299, 0.96059601,...]
#         discounts = [gamma**k for k in range(len(rewards)+1)]
        
#         # [1.0, 0.99, 0.9801, 0.970299, 0.96059601,..] for each reward equals to 1
#         discounted_rewards = [discount*reward for discount, reward in zip(discounts, rewards)]

#         # a scalar
#         discounted_return = sum(discounted_rewards)
        
#         # calculate discounted return at each time step
#         discounted_return_each_step = []
#         g_value = 0
#         for discounted_reward_each_step in reversed(discounted_rewards):
#             g_value += discounted_reward_each_step
#             discounted_return_each_step.append(g_value)
        
#         discounted_return_each_step = discounted_return_each_step[::-1]
        
#         losses = []
#         for log_prob, g_step in zip(log_prob_selected_actions, discounted_return_each_step):
#             # why not discounted_return at each timestep corresponds to log_pro
#             losses.append(-log_prob * g_step)
        
#         # losses = []
#         # for log_prob in log_prob_selected_actions:
#         #     # why not discounted_return at each timestep corresponds to log_pro
#         #     losses.append(-log_prob * discounted_return)
        
#         loss = sum(losses)
#         optimizier.zero_grad()
#         loss.backward()
#         optimizier.step()
                
#         print('Episode {}\tAverage Score: {:.2f}'.format(i_episode, loss.detach().numpy()))

# %%
model = Policy(n_states, n_hidden, n_actions)
optimizier = optim.Adam(model.parameters(), lr=1e-2)

# %%
reinforce(model, optimizier, n_training_episodes=100)
# Out:
# Episode 0	Average Score: 228.36
# Episode 1	Average Score: 39.30
# Episode 2	Average Score: 58.70
# Episode 3	Average Score: 28.25
# Episode 4	Average Score: 46.56
# Episode 5	Average Score: 24.80
# Episode 6	Average Score: 22.60
# Episode 7	Average Score: 7.56
# Episode 8	Average Score: 6.41
# Episode 9	Average Score: 5.03
# Episode 10	Average Score: 3.84
# Episode 11	Average Score: 3.28
# Episode 12	Average Score: 2.12
# Episode 13	Average Score: 2.15
# Episode 14	Average Score: 1.80
# Episode 15	Average Score: 1.64
# Episode 16	Average Score: 1.12
# Episode 17	Average Score: 1.07
# Episode 18	Average Score: 0.75
# Episode 19	Average Score: 0.60
# Episode 20	Average Score: 0.76
# Episode 21	Average Score: 0.60
# Episode 22	Average Score: 0.44
# Episode 23	Average Score: 0.34
# Episode 24	Average Score: 0.37
# Episode 25	Average Score: 0.31
# Episode 26	Average Score: 0.26
# Episode 27	Average Score: 0.25
# Episode 28	Average Score: 0.19
# Episode 29	Average Score: 0.14
# Episode 30	Average Score: 0.18
# Episode 31	Average Score: 0.13
# Episode 32	Average Score: 0.10
# Episode 33	Average Score: 0.11
# Episode 34	Average Score: 53.98
# Episode 35	Average Score: 0.11
# Episode 36	Average Score: 0.10
# Episode 37	Average Score: 52.03
# Episode 38	Average Score: 0.10
# Episode 39	Average Score: 0.15
# Episode 40	Average Score: 0.26
# Episode 41	Average Score: 0.21
# Episode 42	Average Score: 0.28
# Episode 43	Average Score: 0.29
# Episode 44	Average Score: 0.24
# Episode 45	Average Score: 0.22
# Episode 46	Average Score: 0.30
# Episode 47	Average Score: 0.42
# Episode 48	Average Score: 0.37
# Episode 49	Average Score: 0.49
# Episode 50	Average Score: 0.39
# Episode 51	Average Score: 0.40
# Episode 52	Average Score: 0.38
# Episode 53	Average Score: 0.46
# Episode 54	Average Score: 0.52
# Episode 55	Average Score: 0.37
# Episode 56	Average Score: 0.41
# Episode 57	Average Score: 0.34
# Episode 58	Average Score: 0.36
# Episode 59	Average Score: 0.35
# Episode 60	Average Score: 0.35
# Episode 61	Average Score: 0.29
# Episode 62	Average Score: 41.63
# Episode 63	Average Score: 0.44
# Episode 64	Average Score: 0.33
# Episode 65	Average Score: 0.47
# Episode 66	Average Score: 0.42
# Episode 67	Average Score: 0.43
# Episode 68	Average Score: 0.36
# Episode 69	Average Score: 0.47
# Episode 70	Average Score: 0.45
# Episode 71	Average Score: 0.53
# Episode 72	Average Score: 0.54
# Episode 73	Average Score: 0.38
# Episode 74	Average Score: 0.45
# Episode 75	Average Score: 0.66
# Episode 76	Average Score: 0.43
# Episode 77	Average Score: 0.52
# Episode 78	Average Score: 0.42
# Episode 79	Average Score: 0.42
# Episode 80	Average Score: 0.43
# Episode 81	Average Score: 0.48
# Episode 82	Average Score: 0.46
# Episode 83	Average Score: 0.33
# Episode 84	Average Score: 0.31
# Episode 85	Average Score: 0.42
# Episode 86	Average Score: 0.44
# Episode 87	Average Score: 0.41
# Episode 88	Average Score: 0.39
# Episode 89	Average Score: 0.30
# Episode 90	Average Score: 0.28
# Episode 91	Average Score: 0.28
# Episode 92	Average Score: 0.36
# Episode 93	Average Score: 0.26
# Episode 94	Average Score: 0.27
# Episode 95	Average Score: 0.31
# Episode 96	Average Score: 0.29
# Episode 97	Average Score: 0.20
# Episode 98	Average Score: 0.19
# Episode 99	Average Score: 0.19

# %%
evaluate_agent(model, env, max_steps=1000, n_eval_episodes=10)
# Out:
# (18.3, 5.119570294468081)

# %%
evaluate_agent(model, env, max_steps=1000, n_eval_episodes=10)
# Out:
# (9.7, 0.45825756949558405)

# %%
rewards = torch.tensor([5, 2, 3, 4])
actions = torch.tensor([0, 1, 2, 3])

# %%
log_probs = torch.tensor([-1, -2, -3, -4])
